# %%
import numpy as np

# %%
a = np.array([[1, 2, 3],
              [4, 5, 6]])

# %%
a.shape
(2, 3)
# Out:
# (2, 3)

# %%
libri = np.array([2,4,6])
print(libri)
figurine = np.array([1,3,5])
print(figurine)
patrimonio = libri + figurine
print(patrimonio)
# Out:
# [2 4 6]
# [1 3 5]
# [ 3  7 11]

# %%
librivecchi = [2,4,6]
print(librivecchi)
figurinevecchie = [1,3,5]
print(figurinevecchie)
patrimoniovecchio = librivecchi + figurinevecchie
print(patrimoniovecchio)
# Out:
# [2, 4, 6]
# [1, 3, 5]
# [2, 4, 6, 1, 3, 5]

# %%
# Lista numpy di un'immagine bidimensionale
pic = np.random.randn(3,4,)
print(pic)
# Out:
# [[-1.34955282 -0.01743846  1.18222969 -0.21861599]
#  [ 0.57161529  0.22606998 -0.50009676 -0.69167195]
#  [-0.31030433  0.13003543  0.94982555 -0.40675601]]

# %%
# Lista numpy di un'immagine tridimensionale
pic = np.random.randn(3,4,2)
print(pic)
# Out:
# [[[ 0.01315553  1.25279989]
#   [ 2.18602894 -0.5124701 ]
#   [-0.90425077  0.13091484]
#   [ 0.12147522  1.30238526]]
#
#  [[ 0.7414722  -0.05124904]
#   [-0.32330655  0.92160612]
#   [-0.60569665 -0.92986249]
#   [-0.80979533  0.58200888]]
#
#  [[ 1.15207595  1.00856163]
#   [-0.74292386  0.32742227]
#   [-1.10540066 -0.67313093]
#   [-0.58202439  0.82068123]]]

# %%
import pandas as pd

# %%
diagnosis = pd.read_csv('data.csv')

# %%
diagnosis.head(10)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
# 5    843786         M        12.45         15.70           82.57      477.1
# 6    844359         M        18.25         19.98          119.60     1040.0
# 7  84458202         M        13.71         20.83           90.20      577.9
# 8    844981         M        13.00         21.82           87.50      519.8
# 9  84501001         M        12.46         24.04           83.97      475.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
diagnosis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...
